# %% [markdown]
# # Proyecto: Sistema de Recomendación de Libros Gutenberg con PySpark
#
# Este Proyecto fue elaborado por Gerardo Gael Gallardo Garcia del grupo 5-2

# %% [markdown]
# ## Paso 1: Descarga de Libros
# Se descargaron 100 libros de la pagina de gutenberg

# %%
import re
import os
import requests

from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor

def get_links(n: int | list[int] = -1) -> tuple[list[str], list[str]]:
    """Gets the urls for books in the Gutenberg project with numbers `n`."""
    assert n == -1 or min(n) > 0, ( "n can only take values greater than zero "
                                    "or -1 if all links are desired" )
    url = "https://www.gutenberg.org/browse/scores/top"
    try:
        response = requests.get(url)
        parser = BeautifulSoup(response.text, 'html.parser')

        ordered_list = parser.find('ol')
        list_items = ordered_list.find_all('li')

        if(n != -1):
            list_filtered = [list_items[i-1] for i in list(n)]
        else:
            list_filtered = list_items

        prefix = "https://www.gutenberg.org"
        suffix = ".txt.utf-8"
        links, titles = [], []

        for li in list_filtered:
            links.append(prefix + li.find("a").get("href") + suffix)

            title = re.sub(r'\s+', '_', li.get_text())
            title = re.sub(r'_\(\d+\)$', '', title)
            title += '.txt'
            titles.append(title)

        return links, titles

    except requests.exceptions.RequestException:
        print("wrong url for Gutenberg project")


def download_file(url, name):
    response = requests.get(url, stream=True)
    with open(name, mode='wb') as file:
        for chunk in response.iter_content(chunk_size=10 * 1024):
            file.write(chunk)
    print(f"Downloaded file: {name}")


def store_files(links, names, folder):
    os.makedirs(folder, exist_ok=True)  # Ensure folder exists
    filepaths = [os.path.join(folder, name) for name in names]

    with ThreadPoolExecutor() as executor:
        executor.map(download_file, links, filepaths)


def store_files_slow(links, names, folder):
    os.makedirs(folder, exist_ok=True)
    for url, name in zip(links, names):
        download_file(url, os.path.join(folder, name))


def main(n=-1, folder="gutenberg_books"):
    links, titles = get_links(n)
    store_files(links, titles, folder)
    print("Done")


n = range(1, 101)
main(n, folder="Libros")
# Out:
# Downloaded file: Libros/The_Strange_Case_of_Dr._Jekyll_and_Mr._Hyde_by_Robert_Louis_Stevenson.txt
# Downloaded file: Libros/Pride_and_Prejudice_by_Jane_Austen.txt
# Downloaded file: Libros/Frankenstein;_Or,_The_Modern_Prometheus_by_Mary_Wollstonecraft_Shelley.txt
# Downloaded file: Libros/The_King_in_Yellow_by_Robert_W._Chambers.txt
# Downloaded file: Libros/A_Christmas_Carol_in_Prose;_Being_a_Ghost_Story_of_Christmas_by_Charles_Dickens.txt
# Downloaded file: Libros/Little_Women;_Or,_Meg,_Jo,_Beth,_and_Amy_by_Louisa_May_Alcott.txt
# Downloaded file: Libros/Moby_Dick;_Or,_The_Whale_by_Herman_Melville.txt
# Downloaded file: Libros/A_Doll's_House_:_a_play_by_Henrik_Ibsen.txt
# Downloaded file: Libros/The_Scarlet_Letter_by_Nathaniel_Hawthorne.txt
# Downloaded file: Libros/Beowulf:_An_Anglo-Saxon_Epic_Poem.txt
# Downloaded file: Libros/Alice's_Adventures_in_Wonderland_by_Lewis_Carroll.txt
# Downloaded file: Libros/A_Room_with_a_View_by_E._M._Forster.txt
# Downloaded file: Libros/Romeo_and_Juliet_by_William_Shakespeare.txt
# Downloaded file: Libros/Twas_the_Night_before_Christmas:_A_Visit_from_St._Nicholas_by_Clement_Clarke_Moore.txt
# Downloaded file: Libros/A_Modest_Proposal_by_Jonathan_Swift.txt
# Downloaded file: Libros/The_Blue_Castle:_a_novel_by_L._M._Montgomery.txt
# Downloaded file: Libros/Crime_and_Punishment_by_Fyodor_Dostoyevsky.txt
# Downloaded file: Libros/The_Picture_of_Dorian_Gray_by_Oscar_Wilde.txt
# Downloaded file: Libros/The_Great_Gatsby_by_F._Scott_Fitzgerald.txt
# Downloaded file: Libros/The_Importance_of_Being_Earnest:_A_Trivial_Comedy_for_Serious_People_by_Oscar_Wilde.txt
# Downloaded file: Libros/Cranford_by_Elizabeth_Cleghorn_Gaskell.txt
# Downloaded file: Libros/The_Adventures_of_Ferdinand_Count_Fathom_—_Complete_by_T._Smollett.txt
# Downloaded file: Libros/The_Enchanted_April_by_Elizabeth_Von_Arnim.txt
# Downloaded file: Libros/The_Adventures_of_Roderick_Random_by_T._Smollett.txt
# Downloaded file: Libros/History_of_Tom_Jones,_a_Foundling_by_Henry_Fielding.txt
# Downloaded file: Libros/Jane_Eyre:_An_Autobiography_by_Charlotte_Brontë.txt
# Downloaded file: Libros/Adventures_of_Huckleberry_Finn_by_Mark_Twain.txt
# Downloaded file: Libros/Middlemarch_by_George_Eliot.txt
# Downloaded file: Libros/My_Life_—_Volume_1_by_Richard_Wagner.txt
# Downloaded file: Libros/Dracula_by_Bram_Stoker.txt
# Downloaded file: Libros/Leviathan_by_Thomas_Hobbes.txt
# Downloaded file: Libros/The_Adventures_of_Sherlock_Holmes_by_Arthur_Conan_Doyle.txt
# Downloaded file: Libros/The_Contemporary_Review,_Volume_36,_October_1879_by_Various.txt
# Downloaded file: Libros/Wuthering_Heights_by_Emily_Brontë.txt
# Downloaded file: Libros/Metamorphosis_by_Franz_Kafka.txt
# Downloaded file: Libros/Great_Expectations_by_Charles_Dickens.txt
# Downloaded file: Libros/The_Expedition_of_Humphry_Clinker_by_T._Smollett.txt
# Downloaded file: Libros/The_Count_of_Monte_Cristo_by_Alexandre_Dumas_and_Auguste_Maquet.txt
# Downloaded file: Libros/Thus_Spake_Zarathustra:_A_Book_for_All_and_None_by_Friedrich_Wilhelm_Nietzsche.txt
# Downloaded file: Libros/Three_Men:_A_Novel_by_Maksim_Gorky.txt
# Downloaded file: Libros/How_to_Observe:_Morals_and_Manners_by_Harriet_Martineau.txt
# Downloaded file: Libros/Second_Treatise_of_Government_by_John_Locke.txt
# Downloaded file: Libros/Walden,_and_On_The_Duty_Of_Civil_Disobedience_by_Henry_David_Thoreau.txt
# Downloaded file: Libros/The_Brothers_Karamazov_by_Fyodor_Dostoyevsky.txt
# Downloaded file: Libros/The_Prince_by_Niccolò_Machiavelli.txt
# Downloaded file: Libros/Grimms'_Fairy_Tales_by_Jacob_Grimm_and_Wilhelm_Grimm.txt
# Downloaded file: Libros/Twenty_years_after_by_Alexandre_Dumas_and_Auguste_Maquet.txt
# Downloaded file: Libros/The_Black_Parrot_:_by_Harry_Hervey.txt
# Downloaded file: Libros/White_Nights_and_Other_Stories_by_Fyodor_Dostoyevsky.txt
# Downloaded file: Libros/Ulysses_by_James_Joyce.txt
# Downloaded file: Libros/Anne_of_Green_Gables_by_L._M._Montgomery.txt
# Downloaded file: Libros/Beyond_Good_and_Evil_by_Friedrich_Wilhelm_Nietzsche.txt
# Downloaded file: Libros/The_Iliad_by_Homer.txt
# Downloaded file: Libros/Spoon_River_Anthology_by_Edgar_Lee_Masters.txt
# Downloaded file: Libros/The_divine_comedy_by_Dante_Alighieri.txt
# Downloaded file: Libros/The_Confessions_of_St._Augustine_by_Bishop_of_Hippo_Saint_Augustine.txt
# Downloaded file: Libros/The_Adventures_of_Tom_Sawyer,_Complete_by_Mark_Twain.txt
# Downloaded file: Libros/The_Book_of_Christmas_by_Various.txt
# Downloaded file: Libros/The_Wonderful_Wizard_of_Oz_by_L._Frank_Baum.txt
# Downloaded file: Libros/The_Yellow_Wallpaper_by_Charlotte_Perkins_Gilman.txt
# Downloaded file: Libros/The_analysis_of_matter_by_Bertrand_Russell.txt
# Downloaded file: Libros/War_and_Peace_by_graf_Leo_Tolstoy.txt
# Downloaded file: Libros/Doctrina_Christiana.txt
# Downloaded file: Libros/The_Souls_of_Black_Folk_by_W._E._B._Du_Bois.txt
# Downloaded file: Libros/Marjorie_at_Seacote_by_Carolyn_Wells.txt
# Downloaded file: Libros/Tractatus_Logico-Philosophicus_by_Ludwig_Wittgenstein.txt
# Downloaded file: Libros/The_Complete_Works_of_William_Shakespeare_by_William_Shakespeare.txt
# Downloaded file: Libros/Narrative_of_the_Life_of_Frederick_Douglass,_an_American_Slave_by_Frederick_Douglass.txt
# Downloaded file: Libros/Gulliver's_Travels_into_Several_Remote_Nations_of_the_World_by_Jonathan_Swift.txt
# Downloaded file: Libros/A_Tale_of_Two_Cities_by_Charles_Dickens.txt
# Downloaded file: Libros/The_Works_of_Edgar_Allan_Poe_—_Volume_2_by_Edgar_Allan_Poe.txt
# Downloaded file: Libros/The_Tragical_History_of_Doctor_Faustus_by_Christopher_Marlowe.txt
# Downloaded file: Libros/The_three_glass_eyes_:_by_William_Le_Queux.txt
# Downloaded file: Libros/The_Hound_of_the_Baskervilles_by_Arthur_Conan_Doyle.txt
# Downloaded file: Libros/Bleak_House_by_Charles_Dickens.txt
# Downloaded file: Libros/Treasure_Island_by_Robert_Louis_Stevenson.txt
# Downloaded file: Libros/The_Republic_by_Plato.txt
# Downloaded file: Libros/The_Wars_of_Religion_in_France_1559-1576_by_James_Westfall_Thompson.txt
# Downloaded file: Libros/Sense_and_Sensibility_by_Jane_Austen.txt
# Downloaded file: Libros/Moby_Multiple_Language_Lists_of_Common_Words_by_Grady_Ward.txt
# Downloaded file: Libros/On_Liberty_by_John_Stuart_Mill.txt
# Downloaded file: Libros/Anna_Karenina_by_graf_Leo_Tolstoy.txt
# Downloaded file: Libros/The_Legend_of_Sleepy_Hollow_by_Washington_Irving.txt
# Downloaded file: Libros/The_lesser_Key_of_Solomon,_Goetia,_the_book_of_evil_spirits_:.txt
# Downloaded file: Libros/Frankenstein;_Or,_The_Modern_Prometheus_by_Mary_Wollstonecraft_Shelley.txt
# Downloaded file: Libros/British_Pomology_by_Robert_Hogg.txt
# Downloaded file: Libros/Tess_of_the_d'Urbervilles:_A_Pure_Woman_by_Thomas_Hardy.txt
# Downloaded file: Libros/Constance_Trescot_by_S._Weir_Mitchell.txt
# Downloaded file: Libros/A_Concise_Anglo-Saxon_Dictionary_by_J._R._Clark_Hall.txt
# Downloaded file: Libros/Meditations_by_Emperor_of_Rome_Marcus_Aurelius.txt
# Downloaded file: Libros/A_Christmas_Carol_by_Charles_Dickens.txt
# Downloaded file: Libros/Little_Women_by_Louisa_May_Alcott.txt
# Downloaded file: Libros/池北偶談_by_Shizhen_Wang.txt
# Downloaded file: Libros/Heart_of_Darkness_by_Joseph_Conrad.txt
# Downloaded file: Libros/The_Odyssey_by_Homer.txt
# Downloaded file: Libros/The_Interesting_Narrative_of_the_Life_of_Olaudah_Equiano,_Or_Gustavus_Vassa,_The_African_by_Equiano.txt
# Downloaded file: Libros/Society_in_America,_Volume_1_(of_2)_by_Harriet_Martineau.txt
# Downloaded file: Libros/The_Story_of_Our_Hymns_by_Ernest_Edwin_Ryden.txt
# Downloaded file: Libros/The_Philosophy_of_Auguste_Comte_by_Lucien_Lévy-Bruhl.txt
# Downloaded file: Libros/A_History_of_the_Nineteenth_Century,_Year_by_Year._Volume_2_(of_3)_by_Edwin_Emerson.txt
# Done

# %% [markdown]
# ## Paso 2: Limpieza de Datos
# Este script elimina los datos no pertenecientes al libro, se podria considerar que son datos basuras implementados por gutenberg, los elimina al inicio y al final. Tambien elimina 3 libros no deseados pues estan en otro idioma o en un formato ilegible y elimina los caracteres especiales de los nombres de los libros pues Spark no puede leerlos

# %%
import os
import re


# Libros a eliminar 
LIBROS_A_ELIMINAR = {
    "冷眼观_by_Junqing_Wang.txt",
    "池北偶談_by_Shizhen_Wang.txt",
    "Tractatus_Logico-Philosophicus_by_Ludwig_Wittgenstein.txt"
}


def normalizar_nombre_archivo(folder, filename):
    """
    Elimina caracteres especiales del nombre del archivo
    para evitar problemas con Spark y URIs.
    """
    nombre_limpio = re.sub(r"[^\w\-.]", "_", filename)

    if nombre_limpio != filename:
        old_path = os.path.join(folder, filename)
        new_path = os.path.join(folder, nombre_limpio)
        os.rename(old_path, new_path)
        print(f"✏ Renombrado: {filename} → {nombre_limpio}")
        return nombre_limpio

    return filename


def clean_gutenberg_text(path):
    """
    Elimina encabezados y pies de Project Gutenberg
    sobrescribiendo el archivo original.
    """
    try:
        with open(path, "r", encoding="utf-8", errors="ignore") as f:
            text = f.read()

        start = re.search(
            r"\*\*\*\s*START OF THE PROJECT GUTENBERG EBOOK.*?\*\*\*",
            text,
            re.IGNORECASE | re.DOTALL
        )
        end = re.search(
            r"\*\*\*\s*END OF THE PROJECT GUTENBERG EBOOK.*?\*\*\*",
            text,
            re.IGNORECASE | re.DOTALL
        )

        if not start or not end:
            print(f"⚠️  Sin marcadores Gutenberg: {os.path.basename(path)}")
            return False

        clean_text = text[start.end():end.start()].strip()

        with open(path, "w", encoding="utf-8") as f:
            f.write(clean_text)

        print(f"✔ Limpiado: {os.path.basename(path)}")
        return True

    except Exception as e:
        print(f"❌ Error en {os.path.basename(path)}: {e}")
        return False


def clean_all_books(folder):
    folder = os.path.expanduser(folder)

    for file in os.listdir(folder):

        # Eliminar libros prohibidos
        if file in LIBROS_A_ELIMINAR:
            os.remove(os.path.join(folder, file))
            continue

        if not file.endswith(".txt"):
            continue

        # Normalizar nombre del archivo
        file = normalizar_nombre_archivo(folder, file)

      
        path = os.path.join(folder, file)

        clean_gutenberg_text(path)
            




if __name__ == "__main__":
    clean_all_books("~/Sistdist/Libros")
    print("Finalizado!")
# Out:
# ✔ Limpiado: Pride_and_Prejudice_by_Jane_Austen.txt
# ✔ Limpiado: Metamorphosis_by_Franz_Kafka.txt
# ✏ Renombrado: A_Doll's_House_:_a_play_by_Henrik_Ibsen.txt → A_Doll_s_House___a_play_by_Henrik_Ibsen.txt
# ✔ Limpiado: A_Doll_s_House___a_play_by_Henrik_Ibsen.txt
# ✔ Limpiado: Dracula_by_Bram_Stoker.txt
# ✔ Limpiado: The_Tragical_History_of_Doctor_Faustus_by_Christopher_Marlowe.txt
# ✔ Limpiado: The_Picture_of_Dorian_Gray_by_Oscar_Wilde.txt
# ✔ Limpiado: Heart_of_Darkness_by_Joseph_Conrad.txt
# ✏ Renombrado: The_Interesting_Narrative_of_the_Life_of_Olaudah_Equiano,_Or_Gustavus_Vassa,_The_African_by_Equiano.txt → The_Interesting_Narrative_of_the_Life_of_Olaudah_Equiano__Or_Gustavus_Vassa__The_African_by_Equiano.txt
# ✔ Limpiado: The_Interesting_Narrative_of_the_Life_of_Olaudah_Equiano__Or_Gustavus_Vassa__The_African_by_Equiano.txt
# ✏ Renombrado: Moby_Dick;_Or,_The_Whale_by_Herman_Melville.txt → Moby_Dick__Or__The_Whale_by_Herman_Melville.txt
# ✔ Limpiado: Moby_Dick__Or__The_Whale_by_Herman_Melville.txt
# ✔ Limpiado: The_Expedition_of_Humphry_Clinker_by_T._Smollett.txt
# ✏ Renombrado: The_Blue_Castle:_a_novel_by_L._M._Montgomery.txt → The_Blue_Castle__a_novel_by_L._M._Montgomery.txt
# ✔ Limpiado: The_Blue_Castle__a_novel_by_L._M._Montgomery.txt
# ✏ Renombrado: The_three_glass_eyes_:_by_William_Le_Queux.txt → The_three_glass_eyes___by_William_Le_Queux.txt
# ✔ Limpiado: The_three_glass_eyes___by_William_Le_Queux.txt
# ✔ Limpiado: Middlemarch_by_George_Eliot.txt
# ✔ Limpiado: Treasure_Island_by_Robert_Louis_Stevenson.txt
# ✔ Limpiado: The_Book_of_Christmas_by_Various.txt
# ✏ Renombrado: Society_in_America,_Volume_1_(of_2)_by_Harriet_Martineau.txt → Society_in_America__Volume_1__of_2__by_Harriet_Martineau.txt
# ✔ Limpiado: Society_in_America__Volume_1__of_2__by_Harriet_Martineau.txt
# ✏ Renombrado: Twas_the_Night_before_Christmas:_A_Visit_from_St._Nicholas_by_Clement_Clarke_Moore.txt → Twas_the_Night_before_Christmas__A_Visit_from_St._Nicholas_by_Clement_Clarke_Moore.txt
# ✔ Limpiado: Twas_the_Night_before_Christmas__A_Visit_from_St._Nicholas_by_Clement_Clarke_Moore.txt
# ✔ Limpiado: The_Strange_Case_of_Dr._Jekyll_and_Mr._Hyde_by_Robert_Louis_Stevenson.txt
# ✔ Limpiado: Crime_and_Punishment_by_Fyodor_Dostoyevsky.txt
# ✔ Limpiado: Beyond_Good_and_Evil_by_Friedrich_Wilhelm_Nietzsche.txt
# ✔ Limpiado: Moby_Multiple_Language_Lists_of_Common_Words_by_Grady_Ward.txt
# ✏ Renombrado: Walden,_and_On_The_Duty_Of_Civil_Disobedience_by_Henry_David_Thoreau.txt → Walden__and_On_The_Duty_Of_Civil_Disobedience_by_Henry_David_Thoreau.txt
# ✔ Limpiado: Walden__and_On_The_Duty_Of_Civil_Disobedience_by_Henry_David_Thoreau.txt
# ✏ Renombrado: The_Black_Parrot_:_by_Harry_Hervey.txt → The_Black_Parrot___by_Harry_Hervey.txt
# ✔ Limpiado: The_Black_Parrot___by_Harry_Hervey.txt
# ✔ Limpiado: The_Wars_of_Religion_in_France_1559-1576_by_James_Westfall_Thompson.txt
# ✔ Limpiado: Great_Expectations_by_Charles_Dickens.txt
# ✔ Limpiado: The_Hound_of_the_Baskervilles_by_Arthur_Conan_Doyle.txt
# ✔ Limpiado: White_Nights_and_Other_Stories_by_Fyodor_Dostoyevsky.txt
# ✔ Limpiado: A_Concise_Anglo-Saxon_Dictionary_by_J._R._Clark_Hall.txt
# ✔ Limpiado: Doctrina_Christiana.txt
# ✔ Limpiado: The_Adventures_of_Sherlock_Holmes_by_Arthur_Conan_Doyle.txt
# ✔ Limpiado: The_Prince_by_Niccolò_Machiavelli.txt
# ✔ Limpiado: The_Adventures_of_Roderick_Random_by_T._Smollett.txt
# ✔ Limpiado: The_Philosophy_of_Auguste_Comte_by_Lucien_Lévy-Bruhl.txt
# ✏ Renombrado: History_of_Tom_Jones,_a_Foundling_by_Henry_Fielding.txt → History_of_Tom_Jones__a_Foundling_by_Henry_Fielding.txt
# ✔ Limpiado: History_of_Tom_Jones__a_Foundling_by_Henry_Fielding.txt
# ✔ Limpiado: Constance_Trescot_by_S._Weir_Mitchell.txt
# ✔ Limpiado: Marjorie_at_Seacote_by_Carolyn_Wells.txt
# ✔ Limpiado: The_Great_Gatsby_by_F._Scott_Fitzgerald.txt
# ✏ Renombrado: Narrative_of_the_Life_of_Frederick_Douglass,_an_American_Slave_by_Frederick_Douglass.txt → Narrative_of_the_Life_of_Frederick_Douglass__an_American_Slave_by_Frederick_Douglass.txt
# ✔ Limpiado: Narrative_of_the_Life_of_Frederick_Douglass__an_American_Slave_by_Frederick_Douglass.txt
# ✏ Renombrado: The_Adventures_of_Tom_Sawyer,_Complete_by_Mark_Twain.txt → The_Adventures_of_Tom_Sawyer__Complete_by_Mark_Twain.txt
# ✔ Limpiado: The_Adventures_of_Tom_Sawyer__Complete_by_Mark_Twain.txt
# ✔ Limpiado: The_Story_of_Our_Hymns_by_Ernest_Edwin_Ryden.txt
# ✔ Limpiado: The_Odyssey_by_Homer.txt
# ✔ Limpiado: The_Souls_of_Black_Folk_by_W._E._B._Du_Bois.txt
# ✔ Limpiado: The_Complete_Works_of_William_Shakespeare_by_William_Shakespeare.txt
# ✔ Limpiado: A_Tale_of_Two_Cities_by_Charles_Dickens.txt
# ✔ Limpiado: The_Enchanted_April_by_Elizabeth_Von_Arnim.txt
# ✏ Renombrado: The_Adventures_of_Ferdinand_Count_Fathom_—_Complete_by_T._Smollett.txt → The_Adventures_of_Ferdinand_Count_Fathom___Complete_by_T._Smollett.txt
# ✔ Limpiado: The_Adventures_of_Ferdinand_Count_Fathom___Complete_by_T._Smollett.txt
# ✔ Limpiado: Cranford_by_Elizabeth_Cleghorn_Gaskell.txt
# ✏ Renombrado: A_History_of_the_Nineteenth_Century,_Year_by_Year._Volume_2_(of_3)_by_Edwin_Emerson.txt → A_History_of_the_Nineteenth_Century__Year_by_Year._Volume_2__of_3__by_Edwin_Emerson.txt
# ✔ Limpiado: A_History_of_the_Nineteenth_Century__Year_by_Year._Volume_2__of_3__by_Edwin_Emerson.txt
# ✏ Renombrado: The_Works_of_Edgar_Allan_Poe_—_Volume_2_by_Edgar_Allan_Poe.txt → The_Works_of_Edgar_Allan_Poe___Volume_2_by_Edgar_Allan_Poe.txt
# ✔ Limpiado: The_Works_of_Edgar_Allan_Poe___Volume_2_by_Edgar_Allan_Poe.txt
# ✔ Limpiado: Leviathan_by_Thomas_Hobbes.txt
# ✏ Renombrado: Grimms'_Fairy_Tales_by_Jacob_Grimm_and_Wilhelm_Grimm.txt → Grimms__Fairy_Tales_by_Jacob_Grimm_and_Wilhelm_Grimm.txt
# ✔ Limpiado: Grimms__Fairy_Tales_by_Jacob_Grimm_and_Wilhelm_Grimm.txt
# ✔ Limpiado: Twenty_years_after_by_Alexandre_Dumas_and_Auguste_Maquet.txt
# ✔ Limpiado: Meditations_by_Emperor_of_Rome_Marcus_Aurelius.txt
# ✏ Renombrado: The_lesser_Key_of_Solomon,_Goetia,_the_book_of_evil_spirits_:.txt → The_lesser_Key_of_Solomon__Goetia__the_book_of_evil_spirits__.txt
# ✔ Limpiado: The_lesser_Key_of_Solomon__Goetia__the_book_of_evil_spirits__.txt
# ✔ Limpiado: Anne_of_Green_Gables_by_L._M._Montgomery.txt
# ✏ Renombrado: My_Life_—_Volume_1_by_Richard_Wagner.txt → My_Life___Volume_1_by_Richard_Wagner.txt
# ✔ Limpiado: My_Life___Volume_1_by_Richard_Wagner.txt
# ✔ Limpiado: Sense_and_Sensibility_by_Jane_Austen.txt
# ✔ Limpiado: Adventures_of_Huckleberry_Finn_by_Mark_Twain.txt
# ✏ Renombrado: Tess_of_the_d'Urbervilles:_A_Pure_Woman_by_Thomas_Hardy.txt → Tess_of_the_d_Urbervilles__A_Pure_Woman_by_Thomas_Hardy.txt
# ✔ Limpiado: Tess_of_the_d_Urbervilles__A_Pure_Woman_by_Thomas_Hardy.txt
# ✏ Renombrado: How_to_Observe:_Morals_and_Manners_by_Harriet_Martineau.txt → How_to_Observe__Morals_and_Manners_by_Harriet_Martineau.txt
# ✔ Limpiado: How_to_Observe__Morals_and_Manners_by_Harriet_Martineau.txt
# ✔ Limpiado: Ulysses_by_James_Joyce.txt
# ✔ Limpiado: War_and_Peace_by_graf_Leo_Tolstoy.txt
# ✔ Limpiado: The_divine_comedy_by_Dante_Alighieri.txt
# ✔ Limpiado: The_Scarlet_Letter_by_Nathaniel_Hawthorne.txt
# ✔ Limpiado: Romeo_and_Juliet_by_William_Shakespeare.txt
# ✔ Limpiado: On_Liberty_by_John_Stuart_Mill.txt
# ✔ Limpiado: The_Republic_by_Plato.txt
# ✏ Renombrado: Jane_Eyre:_An_Autobiography_by_Charlotte_Brontë.txt → Jane_Eyre__An_Autobiography_by_Charlotte_Brontë.txt
# ✔ Limpiado: Jane_Eyre__An_Autobiography_by_Charlotte_Brontë.txt
# ✔ Limpiado: The_King_in_Yellow_by_Robert_W._Chambers.txt
# ✔ Limpiado: The_Iliad_by_Homer.txt
# ✔ Limpiado: A_Modest_Proposal_by_Jonathan_Swift.txt
# ✏ Renombrado: Gulliver's_Travels_into_Several_Remote_Nations_of_the_World_by_Jonathan_Swift.txt → Gulliver_s_Travels_into_Several_Remote_Nations_of_the_World_by_Jonathan_Swift.txt
# ✔ Limpiado: Gulliver_s_Travels_into_Several_Remote_Nations_of_the_World_by_Jonathan_Swift.txt
# ✏ Renombrado: Three_Men:_A_Novel_by_Maksim_Gorky.txt → Three_Men__A_Novel_by_Maksim_Gorky.txt
# ✔ Limpiado: Three_Men__A_Novel_by_Maksim_Gorky.txt
# ⚠️  Sin marcadores Gutenberg: The_analysis_of_matter_by_Bertrand_Russell.txt
# ✏ Renombrado: Alice's_Adventures_in_Wonderland_by_Lewis_Carroll.txt → Alice_s_Adventures_in_Wonderland_by_Lewis_Carroll.txt
# ✔ Limpiado: Alice_s_Adventures_in_Wonderland_by_Lewis_Carroll.txt
# ✔ Limpiado: Bleak_House_by_Charles_Dickens.txt
# ✔ Limpiado: Little_Women_by_Louisa_May_Alcott.txt
# ✔ Limpiado: The_Wonderful_Wizard_of_Oz_by_L._Frank_Baum.txt
# ✔ Limpiado: The_Confessions_of_St._Augustine_by_Bishop_of_Hippo_Saint_Augustine.txt
# ✔ Limpiado: Anna_Karenina_by_graf_Leo_Tolstoy.txt
# ✔ Limpiado: A_Christmas_Carol_by_Charles_Dickens.txt
# ✏ Renombrado: Beowulf:_An_Anglo-Saxon_Epic_Poem.txt → Beowulf__An_Anglo-Saxon_Epic_Poem.txt
# ✔ Limpiado: Beowulf__An_Anglo-Saxon_Epic_Poem.txt
# ✏ Renombrado: The_Importance_of_Being_Earnest:_A_Trivial_Comedy_for_Serious_People_by_Oscar_Wilde.txt → The_Importance_of_Being_Earnest__A_Trivial_Comedy_for_Serious_People_by_Oscar_Wilde.txt
# ✔ Limpiado: The_Importance_of_Being_Earnest__A_Trivial_Comedy_for_Serious_People_by_Oscar_Wilde.txt
# ✔ Limpiado: A_Room_with_a_View_by_E._M._Forster.txt
# ✏ Renombrado: Frankenstein;_Or,_The_Modern_Prometheus_by_Mary_Wollstonecraft_Shelley.txt → Frankenstein__Or__The_Modern_Prometheus_by_Mary_Wollstonecraft_Shelley.txt
# ✔ Limpiado: Frankenstein__Or__The_Modern_Prometheus_by_Mary_Wollstonecraft_Shelley.txt
# ✏ Renombrado: The_Contemporary_Review,_Volume_36,_October_1879_by_Various.txt → The_Contemporary_Review__Volume_36__October_1879_by_Various.txt
# ✔ Limpiado: The_Contemporary_Review__Volume_36__October_1879_by_Various.txt
# ✔ Limpiado: The_Yellow_Wallpaper_by_Charlotte_Perkins_Gilman.txt
# ✏ Renombrado: Thus_Spake_Zarathustra:_A_Book_for_All_and_None_by_Friedrich_Wilhelm_Nietzsche.txt → Thus_Spake_Zarathustra__A_Book_for_All_and_None_by_Friedrich_Wilhelm_Nietzsche.txt
# ✔ Limpiado: Thus_Spake_Zarathustra__A_Book_for_All_and_None_by_Friedrich_Wilhelm_Nietzsche.txt
# ✏ Renombrado: A_Christmas_Carol_in_Prose;_Being_a_Ghost_Story_of_Christmas_by_Charles_Dickens.txt → A_Christmas_Carol_in_Prose__Being_a_Ghost_Story_of_Christmas_by_Charles_Dickens.txt
# ✔ Limpiado: A_Christmas_Carol_in_Prose__Being_a_Ghost_Story_of_Christmas_by_Charles_Dickens.txt
# ✔ Limpiado: The_Count_of_Monte_Cristo_by_Alexandre_Dumas_and_Auguste_Maquet.txt
# ✏ Renombrado: Little_Women;_Or,_Meg,_Jo,_Beth,_and_Amy_by_Louisa_May_Alcott.txt → Little_Women__Or__Meg__Jo__Beth__and_Amy_by_Louisa_May_Alcott.txt
# ✔ Limpiado: Little_Women__Or__Meg__Jo__Beth__and_Amy_by_Louisa_May_Alcott.txt
# ✔ Limpiado: Second_Treatise_of_Government_by_John_Locke.txt
# ⚠️  Sin marcadores Gutenberg: Spoon_River_Anthology_by_Edgar_Lee_Masters.txt
# ✔ Limpiado: The_Brothers_Karamazov_by_Fyodor_Dostoyevsky.txt
# ✔ Limpiado: British_Pomology_by_Robert_Hogg.txt
# ✔ Limpiado: The_Legend_of_Sleepy_Hollow_by_Washington_Irving.txt
# ✔ Limpiado: Wuthering_Heights_by_Emily_Brontë.txt
# Finalizado!

# %% [markdown]
# ## Paso 3: Creación de Vocabularios
# Este script crea un vocabulario de cada 1 de los libros y coloca un contador de las palabras y que tanto se repiten

# %%
import os
import shutil

from pyspark.sql import SparkSession
from pyspark.sql.functions import (
    input_file_name, lower, regexp_replace,
    split, explode, regexp_extract,
    col, expr
)
from pyspark.ml.feature import StopWordsRemover
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number, desc


# SESIÓN SPARK
spark = (
    SparkSession.builder
    .appName("VocabulariosRapidosOrdenados")
    .master("local[*]")
    .config("spark.sql.shuffle.partitions", "200")
    .config("spark.hadoop.mapreduce.fileoutputcommitter.marksuccessfuljobs", "false")
    .getOrCreate()
)


spark.sparkContext.setLogLevel("ERROR")


# CARGAR LIBROS
ruta_libros = "/home/kuatrogs/Sistdist/Libros/*.txt"

df = (
    spark.read.text(ruta_libros)
    .withColumn("filename", input_file_name())
)


# LIMPIEZA Y TOKENIZACIÓN
df = df.withColumn("line", lower("value"))

df = df.withColumn(
    "clean_line",
    regexp_replace("line", r"[^a-z0-9\s]", " ")
)

df = df.withColumn("tokens", split("clean_line", r"\s+"))

remover = StopWordsRemover(
    inputCol="tokens",
    outputCol="filtered",
    stopWords=StopWordsRemover.loadDefaultStopWords("english")
)
df = remover.transform(df)

# Filtrar tokens ANTES del explode
df = df.withColumn(
    "filtered",
    expr("filter(filtered, x -> x IS NOT NULL AND length(x) > 1)")
)

df = df.withColumn("word", explode("filtered"))


# EXTRAER NOMBRE DEL LIBRO
df = df.withColumn(
    "libro",
    regexp_extract("filename", r"([^/]+)\.txt$", 1)
)


# CONTAR FRECUENCIAS
frecuencia = (
    df
    .repartition("libro")
    .groupBy("libro", "word")
    .count()
)


# ORDENAR POR FRECUENCIA (DESC) POR LIBRO
window_libro = Window.partitionBy("libro").orderBy(desc("count"))

frecuencia_ordenada = (
    frecuencia
    .withColumn("rank", row_number().over(window_libro))
    .orderBy("libro", "rank")
)


# ESCRIBIR TODO EN PARALELO
ruta_vocab = "/home/kuatrogs/Sistdist/Vocabularios"
os.makedirs(ruta_vocab, exist_ok=True)

(
    frecuencia_ordenada
    .select("libro", "word", "count")
    .write
    .mode("overwrite")
    .option("sep", "\t")
    .option("header", "false")
    .partitionBy("libro")
    .csv(ruta_vocab)
)


# RENOMBRAR LIBRO
for carpeta in os.listdir(ruta_vocab):
    if not carpeta.startswith("libro="):
        continue

    libro = carpeta.replace("libro=", "")
    carpeta_libro = os.path.join(ruta_vocab, carpeta)

    for f in os.listdir(carpeta_libro):
        if f.startswith("part-"):
            origen = os.path.join(carpeta_libro, f)
            destino = os.path.join(
                ruta_vocab,
                f"vocabulario_{libro}.txt"
            )
            if os.path.exists(destino):
                os.remove(destino)

            os.rename(origen, destino)
            break

    shutil.rmtree(carpeta_libro)


spark.stop()
print("Vocabularios creados!")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/12/10 13:06:56 WARN Utils: Your hostname, kuatrogs-B450M-DS3H-V2, resolves to a loopback address: 127.0.1.1; using 192.168.1.10 instead (on interface enp5s0)
# 25/12/10 13:06:56 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/10 13:07:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Vocabularios creados!

# %% [markdown]
# ## Paso 4: Creación de Matriz de Similitud
# Este script genera la matriz de similitud en un archivo "csv" y limpia los nombres de los libros colocandolos en un formato similar al siguiente: `The_Brothers_Karamazov_by_Fyodor_Dostoyevsky`

# %%
from pyspark.sql import SparkSession, functions as F
from pyspark.sql.functions import input_file_name
import numpy as np
import pandas as pd
import math
import os
import warnings
import logging

# CONFIGURACIÓN
warnings.filterwarnings("ignore")
os.environ["PYARROW_IGNORE_TIMEZONE"] = "1"

for logger in ["py4j", "pyspark", "org.apache.spark"]:
    logging.getLogger(logger).setLevel(logging.CRITICAL)

RUTA_VOCAB = "../Sistdist/Vocabularios/*.txt"
SALIDA_CSV = "../Sistdist/matriz_similitud_vocabularios.csv"

print("Iniciando proceso...")

# SPARK SESSION
spark = (
    SparkSession.builder
    .appName("SimilitudVocabulariosTFIDF_Manual")
    .config("spark.ui.showConsoleProgress", "false")
    .getOrCreate()
)

spark.sparkContext.setLogLevel("OFF")


# 1. Cargar vocabularios 
df = (
    spark.read.text(RUTA_VOCAB)
    .withColumn("archivo", F.regexp_replace(input_file_name(), ".*/", ""))
    .withColumn("archivo", F.regexp_replace("archivo", "^vocabulario_", ""))
    .withColumn("archivo", F.regexp_replace("archivo", r"\.txt$", ""))
)

# Extraer solo la palabra
df = df.withColumn("token", F.split(F.col("value"), r"\s+")[0])



# 2. CONTAR FRECUENCIAS: (doc, palabra, freq)
df_freq = (
    df.groupBy("archivo", "token")
      .agg(F.count("*").alias("freq"))
)

# Convertir a RDD 
rdd_freq = df_freq.rdd.map(lambda x: ((x["archivo"], x["token"]), x["freq"]))



# 3. Convertir a formato (doc, palabra, freq)
def parse_freq_tuple(x):
    return (x[0][0], x[0][1], x[1])

rdd_parsed = rdd_freq.map(parse_freq_tuple)


# 4. TOTAL DE PALABRAS POR DOCUMENTO
doc_totals = (
    rdd_parsed
    .map(lambda x: (x[0], x[2]))
    .reduceByKey(lambda a, b: a + b)
)


# 5. CALCULAR TF 
rdd_doc_word_freq = rdd_parsed.map(lambda x: ((x[0], x[1]), x[2]))

rdd_with_totals = (
    rdd_doc_word_freq
    .map(lambda x: (x[0][0], (x[0][1], x[1])))
    .join(doc_totals)
    .map(lambda x: ((x[0], x[1][0][0]), (x[1][0][1], x[1][1])))
)

rdd_tf = rdd_with_totals.map(lambda x: (x[0], x[1][0] / x[1][1]))


# 6. CALCULAR IDF 
total_docs = doc_totals.count()

# CONTAR EN CUANTOS DOCUMENTOS SE ENCUENTRA LA MISMA PALABRA
rdd_word_doc_count = (
    rdd_parsed
    .map(lambda x: (x[1], x[0]))
    .distinct()
    .map(lambda x: (x[0], 1))
    .reduceByKey(lambda a, b: a + b)
)

rdd_idf = rdd_word_doc_count.map(
    lambda x: (x[0], math.log(total_docs / x[1]))
)


# 7. CALCULAR TF-IDF 
rdd_tf_prep = rdd_tf.map(lambda x: (x[0][1], (x[0][0], x[1])))

rdd_tf_idf = (
    rdd_tf_prep
    .join(rdd_idf)
    .map(lambda x: ((x[1][0][0], x[0]), x[1][0][1] * x[1][1]))
)


# 8. Construcción del vocabulario
vocab_global_indexed = (
    rdd_tf_idf.map(lambda x: x[0][1]).distinct().zipWithIndex()
)

vocab_dict = vocab_global_indexed.collectAsMap()


# 9. Convertir TF-IDF a vectores 
rdd_doc_vectors = (
    rdd_tf_idf
    .map(lambda x: (x[0][0], (vocab_dict[x[0][1]], x[1])))
    .groupByKey()
    .map(lambda x: (x[0], list(x[1])))
)


# 10. Recolectar para similitud coseno
doc_vectors_list = rdd_doc_vectors.collect()
doc_names = [doc[0] for doc in doc_vectors_list]

# convertir a vectores (numpy)
vocab_size = len(vocab_dict)
vectores = np.zeros((len(doc_vectors_list), vocab_size))

for i, (doc, vec) in enumerate(doc_vectors_list):
    for idx, value in vec:
        vectores[i, idx] = value


# 11. CALCULAR SIMILITUD COSENO
norms = np.linalg.norm(vectores, axis=1, keepdims=True)
norms[norms == 0] = 1.0

vectores_norm = vectores / norms
similitud = np.dot(vectores_norm, vectores_norm.T)


# 12. Exportar CSV
df_result = pd.DataFrame(similitud, index=doc_names, columns=doc_names)
df_result.to_csv(SALIDA_CSV, encoding="utf-8", float_format="%.6f")

print("MATRIZ DE SIMILITUD CREADA")

spark.stop()
print("Proceso finalizado correctamente.")
# Out:
# Iniciando proceso...
# MATRIZ DE SIMILITUD CREADA (TF-IDF MANUAL)
# Proceso finalizado correctamente.

# %% [markdown]
# ## Paso 5: Recomendación de Libros
# Este script te recomienda "N" cantidad de libros que sean colocados en la variable `recomendaciones` y para seleccionar el libro cambiar la variable `libro`, teniendo en cuenta el formato de los nombres de la matriz csv generada en el paso anterior

# %%
import pandas as pd
import os


RUTA_MATRIZ = "../Sistdist/matriz_similitud_vocabularios.csv"


def recomendar_libros(libro_preferido: str, n_recomendaciones: int):
    """
    Recomienda N libros basados en similitud coseno TF-IDF.

    Parámetros:
        libro_preferido (str): nombre exacto del libro (archivo)
        recomendaciones (int): número de libros a recomendar

    Retorna:
        DataFrame con libros recomendados y puntaje de similitud
    """

    if not os.path.exists(RUTA_MATRIZ):
        raise FileNotFoundError("No se encontró la bibliotecaS de similitud")

    # Cargar matriz
    df = pd.read_csv(RUTA_MATRIZ, index_col=0)

    if libro_preferido not in df.columns:
        raise ValueError(f"Libro '{libro_preferido}' no existe en la biblioteca")

    # Obtener similitudes del libro favorito
    similitudes = df[libro_preferido]

    # Quitar el mismo libro
    similitudes = similitudes.drop(libro_preferido)

    # Ordenar por similitud (descendente)
    recomendaciones = (
        similitudes
        .sort_values(ascending=False)
        .head(n_recomendaciones)
        .reset_index()
    )

    recomendaciones.columns = ["libro_recomendado", "similitud"]

    return recomendaciones


# EJECUCION
if __name__ == "__main__":

    libro = "Alice_s_Adventures_in_Wonderland_by_Lewis_Carroll"   #Elige un nombre del libro de la matriz
    recomendaciones = 5  #Cantidad de recomendaciones deseadas

    try:
        recs = recomendar_libros(libro, recomendaciones)
        print("\nLibros recomendados:")
        print(recs.to_string(index=False))
    except Exception as e:
        print("Error:", e)
# Out:
# Libros recomendados:
#                           libro_recomendado  similitud
#              Bleak_House_by_Charles_Dickens   0.098878
# The_Wonderful_Wizard_of_Oz_by_L._Frank_Baum   0.096608
#          Three_Men__A_Novel_by_Maksim_Gorky   0.096550
#    Anne_of_Green_Gables_by_L._M._Montgomery   0.092971
#       Great_Expectations_by_Charles_Dickens   0.092949

# %% [markdown]
# ## Paso 6: Palabras Importantes
# Este Script selecciona "N" palabras mas importantes de un libro para poder utilizarlo tienes que cambiar la variable `N` para seleccionar la cantidad de palabras importantes que deseas ver y para cambiar de libro tienes que cambiar la variable `libro` teniendo en cuenta la matriz csv creada en el paso 4

# %%
from pyspark.sql import SparkSession, functions as F
import os

BASE_VOCABULARIOS = "../Sistdist/Vocabularios"


def palabras_descriptivas(libro: str, M: int):
    """
    Regresa M palabras que describen un documento deseado.

    Input:
        libro (str): nombre del libro
        M (int): número de palabras características

    Output:
        Lista de tuplas (palabra, frecuencia)

    Error:
        Lanza ValueError si el libro no existe.
    """

    ruta_libro = f"{BASE_VOCABULARIOS}/vocabulario_{libro}.txt"

    if not os.path.exists(ruta_libro):
        raise ValueError(f"❌ El libro '{libro}' no existe")


    # LECTURA DE DOCUMENTOS
    df = spark.read.text(ruta_libro)

    # PROCESAMIENTO
    df = (
        df.withColumn("split", F.split(F.col("value"), "\t"))
          .withColumn("palabra", F.col("split").getItem(0))
          .withColumn("frecuencia", F.col("split").getItem(1).cast("int"))
          .filter(F.col("frecuencia").isNotNull())
          .select("palabra", "frecuencia")
    )

    resultado = (
        df.orderBy(F.desc("frecuencia"))
          .limit(M)
          .collect()
    )

    return [(r["palabra"], r["frecuencia"]) for r in resultado]



# EJECUCIÓN
if __name__ == "__main__":

    spark = (
        SparkSession.builder
        .appName("PalabrasImportantes")
        .getOrCreate()
    )
    spark.sparkContext.setLogLevel("ERROR")

    libro = "Alice_s_Adventures_in_Wonderland_by_Lewis_Carroll"
    N = 5

    palabras = palabras_descriptivas(libro, N)

    print(f"\n{N} palabras más importantes de '{libro}':\n")
    for palabra, freq in palabras:
        print(f"({palabra}, {freq})")

    spark.stop()
# Out:
# 5 palabras más importantes de 'Alice_s_Adventures_in_Wonderland_by_Lewis_Carroll':
#
# (said, 462)
# (alice, 399)
# (little, 129)
# (one, 104)
# (know, 87)
